# %% [markdown]
# <a href="https://colab.research.google.com/github/alpereyupoglu/DataCamp/blob/master/TEST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.datasets import boston_housing
(X_train,y_train),(X_test,y_test)=boston_housing.load_data()
# Out:
# ...
# 57344/57026 [==============================] - 0s 0us/step

# %%
import numpy as np
type(X_train)
# Out:
# numpy.ndarray

# %%
X_train.shape
# Out:
# (404, 13)

# %%
X_train[:3,:]
# Out:
# array([[1.23247e+00, 0.00000e+00, 8.14000e+00, 0.00000e+00, 5.38000e-01,
#         6.14200e+00, 9.17000e+01, 3.97690e+00, 4.00000e+00, 3.07000e+02,
#         2.10000e+01, 3.96900e+02, 1.87200e+01],
#        [2.17700e-02, 8.25000e+01, 2.03000e+00, 0.00000e+00, 4.15000e-01,
#         7.61000e+00, 1.57000e+01, 6.27000e+00, 2.00000e+00, 3.48000e+02,
#         1.47000e+01, 3.95380e+02, 3.11000e+00],
#        [4.89822e+00, 0.00000e+00, 1.81000e+01, 0.00000e+00, 6.31000e-01,
#         4.97000e+00, 1.00000e+02, 1.33250e+00, 2.40000e+01, 6.66000e+02,
#         2.02000e+01, 3.75520e+02, 3.26000e+00]])

# %%
X_val=X_train[300:,]
y_val=y_train[300:,]

# %%
from keras.models import Sequential

# %%
model=Sequential()

# %%
from keras.layers import Dense, Activation

# %%
model.add(Dense(13, input_dim=13,kernel_initializer="normal",activation="relu"))

# %%
model.add(Dense(6,kernel_initializer="normal",activation="relu"))
model.add(Dense(1,kernel_initializer="normal"))
model.compile(loss="mean_squared_error",optimizer="adam",metrics=["mean_absolute_percentage_error"])

# %%
model.fit(X_train,y_train,batch_size=32,epochs=5000,validation_data=(X_val,y_val))
# Out:
# Görüntülenen çıkış son 5000 satıra kısaltıldı.
# Epoch 2501/5000
# 13/13 [==============================] - 0s 7ms/step - loss: 6.9850 - mean_absolute_percentage_error: 10.1876 - val_loss: 6.0940 - val_mean_absolute_percentage_error: 8.7015
# Epoch 2502/5000
# 13/13 [==============================] - 0s 6ms/step - loss: 7.1050 - mean_absolute_percentage_error: 10.1692 - val_loss: 6.2446 - val_mean_absolute_percentage_error: 8.9380
# Epoch 2503/5000
# 13/13 [==============================] - 0s 7ms/step - loss: 6.9618 - mean_absolute_percentage_error: 10.1036 - val_loss: 6.4388 - val_mean_absolute_percentage_error: 8.7269
# Epoch 2504/5000
# 13/13 [==============================] - 0s 7ms/step - loss: 6.6447 - mean_absolute_percentage_error: 9.9548 - val_loss: 6.8124 - val_mean_absolute_percentage_error: 8.6201
# Epoch 2505/5000
# ...

# %%
sonuc=model.evaluate(X_test,y_test)
# Out:
# 4/4 [==============================] - 0s 2ms/step - loss: 29.6243 - mean_absolute_percentage_error: 15.9013

# %%
for i in range(len(model.metrics_names)):
  print(model.metrics_names[i],":",sonuc[i])
# Out:
# loss : 29.62433433532715
# mean_absolute_percentage_error : 15.901311874389648
